# %% [markdown]
# #Mount drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Clone yolov5 from github repo, code not shown here

# %% [markdown]
# #Change to required folder

# %%
# %cd /content/gdrive/MyDrive/Module1/yolov5
# Out:
# /content/gdrive/MyDrive/Module1/yolov5

# %% [markdown]
# #Check current working directory and folder content

# %%
# !pwd
# !ls
# Out:
# /content/gdrive/MyDrive/Module1/yolov5
# CONTRIBUTING.md  export.py   __pycache__       setup.cfg       val.py
# data		 hubconf.py  README.md	       train.py        yolov5l.pt
# detect.py	 LICENSE     requirements.txt  tutorial.ipynb  yolov5m.pt
# Dockerfile	 models      runs	       utils	       yolov5s.pt

# %% [markdown]
# #Intall yolov5 requirements

# %%
# %pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 4.8 MB/s

# %% [markdown]
# #Import libraries

# %%
import torch
#from yolov5 
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.0-235-ge1a6a0b torch 1.10.0+cu111 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.9/107.7 GB disk)

# %% [markdown]
# # Create data set for training
# Create a folder 'images' with all images and a separate folder called 'labels' which contains txt files with annotations corresponding to each image. txt and jpg file should be named the same. Create a txt file listing the paths to all images to be used for training and another listing the paths to all images for validation. Create a yaml file formated according to the yolov5 tutorial which points to the files just mentioned.

# %% [markdown]
# Check that file paths are valid

# %%
import os
os.getcwd()
print(os.path.exists('/content/gdrive/MyDrive/Module1/data_starfish/images/video_0_9829.jpg'))
print(os.path.exists('/content/gdrive/MyDrive/Module1/data_starfish/images/video_1_3907.jpg'))
print(os.path.exists('/content/gdrive/MyDrive/Module1/data_starfish/train_images.txt'))
print(os.path.exists('/content/gdrive/MyDrive/Module1/data_starfish/valid_images.txt'))
# Out:
# True
# True
# True
# True

# %% [markdown]
# # Train YOLOv5s on starfish images
# Resume function can also be used it run stops for any reason.
# Folder containing run information is automatically created in the yolov5 folder.

# %%
#!python train.py --img 1280 --batch 8 --epochs 10 --data=/content/gdrive/MyDrive/Module1/data_starfish/data.yaml --weights yolov5m.pt 
#!python train.py --resume /content/gdrive/MyDrive/Module1/yolov5/runs/train/exp7/weights/last.pt 
#--cache

#!python train.py --img 1280 --batch 8 --epochs 30 --data=/content/gdrive/MyDrive/Module1/data_starfish/data.yaml --weights /content/gdrive/MyDrive/Module1/yolov5/runs/train/exp7/weights/last.pt
#!python train.py --resume /content/gdrive/MyDrive/Module1/yolov5/runs/train/exp8/weights/last.pt 


#!python train.py --img 1280 --batch 16 --epochs 10 --data=/content/gdrive/MyDrive/Module1/data_starfish/data.yaml --weights yolov5s.pt
#!python train.py --img 1280 --batch 16 --epochs 90 --data=/content/gdrive/MyDrive/Module1/data_starfish/data.yaml --weights /content/gdrive/MyDrive/Module1/yolov5/runs/train/exp9/weights/last.pt

# !python train.py --resume /content/gdrive/MyDrive/Module1/yolov5/runs/train/exp10/weights/last.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=/content/gdrive/MyDrive/Module1/yolov5/runs/train/exp10/weights/last.pt, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 2 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# Resuming training from /content/gdrive/MyDrive/Module1/yolov5/runs/train/exp10/weights/last.pt
# YOLOv5 🚀 v6.0-235-ge1a6a0b torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# #Plot information from the results.csv file

# %%
from utils.plots import plot_results 
plot_results('/content/gdrive/MyDrive/Module1/yolov5/runs/train/exp10/results.csv')  # plot 'results.csv' as 'results.png'

# %% [markdown]
# #Test model on image

# %%
path_to_best = path/to/best.pt

# !python detect.py --weights path_to_best --img IMAGE_SIZE --conf 0.25 --source data/images

# %% [markdown]
# Display results of test

# %%
display.Image(filename='testimage.jpg', width=600)
